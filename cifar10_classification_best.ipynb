# %% [markdown]
# # Import Module

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import timm
import time

import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

import torch
import torchvision
import torchvision.transforms as transforms

# %%
CFG={'BATCH_SIZE' : 128,
     'LR' : 0.001,
     'EPOCHS' : 100}

# %% [markdown]
# # Define GPU

# %%
if torch.cuda.is_available():
    device="cuda"
else:
    device="cpu"
    
print(f"device  : {device}")
# Out:
# device  : cuda

# %% [markdown]
# # SEED

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED']=str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=True

# %% [markdown]
# # Data

# %% [markdown]
# Define Class

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# # Directly Ensemble

# %%
class ResNet18(nn.Module):
    def __init__(self, classes=10, pretrained=True) -> None:
        super().__init__()
        self.model=timm.create_model('resnet18', pretrained=pretrained)

        input_features=self.model.fc.in_features
        self.model.fc=nn.Linear(input_features, classes, bias=True)

    def forward(self, x):
        x=self.model(x)
        return x

# %%
def train_loop(epoch, model, dataloader, optimizer, loss_fn):
    trainloss=[]
    trainacc=[]
    size=len(dataloader.dataset)
    for e in range(epoch):
        print(f"--------------------Start {e+1}--------------------")
        start=time.time()

        train_loss=0
        correct=0
        total=0

        model.train()

        for batch, data in enumerate(dataloader):
            X=data[0].to(device)
            y=data[1].to(device)

            optimizer.zero_grad()

            outputs=model(X)
            loss=loss_fn(outputs, y)
            loss.backward()
            optimizer.step()
            
            train_loss+=loss.item()
            _, predicted=outputs.max(1)
          
            total+=y.size(0)
            correct+=predicted.eq(y).sum().item()

            if batch%100==0:
                current=batch*len(X)
                print(f"Batch {batch} loss : {(train_loss/size):>0.3f} [{current:>5d}/{size:>5d}]")

        trainloss.append(train_loss/size)
        trainacc.append((100*correct/size))

        end=time.time()
        print(f"Train\n ACC : {(100*correct/size):>0.1f}%,  LOSS : {(train_loss/size):>0.3f}")
        print(f"Epoch Time : {(end-start) // 60} 분 {((end-start)%60):>0.1f} 초")
        print(f"--------------------End {e+1}--------------------\n\n")

    return trainloss, trainacc

# %%
model_num=5
for i in range(model_num):
    seed=i
    seed_everything(seed)

    degree=random.randint(1, 180)
    train_transform = transforms.Compose([
    #transforms.AugMix(),
    transforms.Resize(256),
    transforms.RandomCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    transforms.RandomHorizontalFlip(),
    #transforms.ColorJitter(brightness=0.5),
    #transforms.RandomVerticalFlip(),
    #transforms.RandomRotation(degrees=degree)
    ])

    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=train_transform)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=CFG['BATCH_SIZE'],
                                            shuffle=True, num_workers=2)
    
    model=ResNet18().to(device)
    loss_fn = nn.CrossEntropyLoss().to(device)

    #base_optimizer = optim.SGD
    optimizer=optim.Adam(model.parameters(),lr=CFG['LR'])

    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20)
    print(f"{seed} Seed Training Start {degree}")
    train_loss, train_acc=train_loop(CFG['EPOCHS'], model, trainloader, optimizer, loss_fn)

    path='D:\\Assignment\\'
    torch.save(model.state_dict(), path+'cifar10_practice_seed_0530' + str(i) + '.pt')
    print(f"{seed} Seed Training done")
    print()
# Out:
# Files already downloaded and verified
# 0 Seed Training Start 99
# --------------------Start 1--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.002 [12800/50000]
# Batch 200 loss : 0.003 [25600/50000]
# Batch 300 loss : 0.003 [38400/50000]
# Train
#  ACC : 81.8%,  LOSS : 0.004
# Epoch Time : 1.0 분 3.9 초
# --------------------End 1--------------------
#
#
# --------------------Start 2--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.001 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.002 [38400/50000]
# Train
#  ACC : 88.8%,  LOSS : 0.003
# Epoch Time : 0.0 분 57.7 초
# --------------------End 2--------------------
#
#
# --------------------Start 3--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.001 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.002 [38400/50000]
# Train
#  ACC : 91.2%,  LOSS : 0.002
# Epoch Time : 0.0 분 57.4 초
# --------------------End 3--------------------
#
#
# --------------------Start 4--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 92.5%,  LOSS : 0.002
# Epoch Time : 0.0 분 56.1 초
# --------------------End 4--------------------
#
#
# --------------------Start 5--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 93.4%,  LOSS : 0.001
# Epoch Time : 0.0 분 57.7 초
# --------------------End 5--------------------
#
#
# --------------------Start 6--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 94.3%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.6 초
# --------------------End 6--------------------
#
#
# --------------------Start 7--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 94.9%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.1 초
# --------------------End 7--------------------
#
#
# --------------------Start 8--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 95.4%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.8 초
# --------------------End 8--------------------
#
#
# --------------------Start 9--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 95.8%,  LOSS : 0.001
# Epoch Time : 0.0 분 55.9 초
# --------------------End 9--------------------
#
#
# --------------------Start 10--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 96.1%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.9 초
# --------------------End 10--------------------
#
#
# --------------------Start 11--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 96.5%,  LOSS : 0.001
# Epoch Time : 0.0 분 55.9 초
# --------------------End 11--------------------
#
#
# --------------------Start 12--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 96.8%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.9 초
# --------------------End 12--------------------
#
#
# --------------------Start 13--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.1%,  LOSS : 0.001
# Epoch Time : 0.0 분 57.9 초
# --------------------End 13--------------------
#
#
# --------------------Start 14--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 97.0%,  LOSS : 0.001
# Epoch Time : 1.0 분 0.8 초
# --------------------End 14--------------------
#
#
# --------------------Start 15--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.4%,  LOSS : 0.001
# Epoch Time : 0.0 분 59.0 초
# --------------------End 15--------------------
#
#
# --------------------Start 16--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.7%,  LOSS : 0.001
# Epoch Time : 0.0 분 58.4 초
# --------------------End 16--------------------
#
#
# --------------------Start 17--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.6%,  LOSS : 0.001
# Epoch Time : 0.0 분 58.4 초
# --------------------End 17--------------------
#
#
# --------------------Start 18--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.9%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.9 초
# --------------------End 18--------------------
#
#
# --------------------Start 19--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.9%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.0 초
# --------------------End 19--------------------
#
#
# --------------------Start 20--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 58.2 초
# --------------------End 20--------------------
#
#
# --------------------Start 21--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 21--------------------
#
#
# --------------------Start 22--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.3 초
# --------------------End 22--------------------
#
#
# --------------------Start 23--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 58.1 초
# --------------------End 23--------------------
#
#
# --------------------Start 24--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.0 초
# --------------------End 24--------------------
#
#
# --------------------Start 25--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 25--------------------
#
#
# --------------------Start 26--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.9 초
# --------------------End 26--------------------
#
#
# --------------------Start 27--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.2 초
# --------------------End 27--------------------
#
#
# --------------------Start 28--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.2 초
# --------------------End 28--------------------
#
#
# --------------------Start 29--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.0 초
# --------------------End 29--------------------
#
#
# --------------------Start 30--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.8%,  LOSS : 0.000
# Epoch Time : 0.0 분 54.5 초
# --------------------End 30--------------------
#
#
# --------------------Start 31--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.9 초
# --------------------End 31--------------------
#
#
# --------------------Start 32--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.4 초
# --------------------End 32--------------------
#
#
# --------------------Start 33--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.9%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.6 초
# --------------------End 33--------------------
#
#
# --------------------Start 34--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.8%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.5 초
# --------------------End 34--------------------
#
#
# --------------------Start 35--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.9%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 35--------------------
#
#
# --------------------Start 36--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.5 초
# --------------------End 36--------------------
#
#
# --------------------Start 37--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.8%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.0 초
# --------------------End 37--------------------
#
#
# --------------------Start 38--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 38--------------------
#
#
# --------------------Start 39--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 39--------------------
#
#
# --------------------Start 40--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.5 초
# --------------------End 40--------------------
#
#
# --------------------Start 41--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 41--------------------
#
#
# --------------------Start 42--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 42--------------------
#
#
# --------------------Start 43--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.5 초
# --------------------End 43--------------------
#
#
# --------------------Start 44--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.9 초
# --------------------End 44--------------------
#
#
# --------------------Start 45--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.0 초
# --------------------End 45--------------------
#
#
# --------------------Start 46--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.6 초
# --------------------End 46--------------------
#
#
# --------------------Start 47--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.4 초
# --------------------End 47--------------------
#
#
# --------------------Start 48--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.1 초
# --------------------End 48--------------------
#
#
# --------------------Start 49--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.7 초
# --------------------End 49--------------------
#
#
# --------------------Start 50--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 50--------------------
#
#
# --------------------Start 51--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 51--------------------
#
#
# --------------------Start 52--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.5 초
# --------------------End 52--------------------
#
#
# --------------------Start 53--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.3 초
# --------------------End 53--------------------
#
#
# --------------------Start 54--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.4 초
# --------------------End 54--------------------
#
#
# --------------------Start 55--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.4 초
# --------------------End 55--------------------
#
#
# --------------------Start 56--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 56--------------------
#
#
# --------------------Start 57--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 57--------------------
#
#
# --------------------Start 58--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.0 초
# --------------------End 58--------------------
#
#
# --------------------Start 59--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.2 초
# --------------------End 59--------------------
#
#
# --------------------Start 60--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.0 초
# --------------------End 60--------------------
#
#
# --------------------Start 61--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.1 초
# --------------------End 61--------------------
#
#
# --------------------Start 62--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.0 초
# --------------------End 62--------------------
#
#
# --------------------Start 63--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.9 초
# --------------------End 63--------------------
#
#
# --------------------Start 64--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 54.3 초
# --------------------End 64--------------------
#
#
# --------------------Start 65--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.7 초
# --------------------End 65--------------------
#
#
# --------------------Start 66--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.3 초
# --------------------End 66--------------------
#
#
# --------------------Start 67--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.3 초
# --------------------End 67--------------------
#
#
# --------------------Start 68--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.7 초
# --------------------End 68--------------------
#
#
# --------------------Start 69--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 69--------------------
#
#
# --------------------Start 70--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 70--------------------
#
#
# --------------------Start 71--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.2 초
# --------------------End 71--------------------
#
#
# --------------------Start 72--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.4 초
# --------------------End 72--------------------
#
#
# --------------------Start 73--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.3 초
# --------------------End 73--------------------
#
#
# --------------------Start 74--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.4 초
# --------------------End 74--------------------
#
#
# --------------------Start 75--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 75--------------------
#
#
# --------------------Start 76--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.0 초
# --------------------End 76--------------------
#
#
# --------------------Start 77--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 77--------------------
#
#
# --------------------Start 78--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.7 초
# --------------------End 78--------------------
#
#
# --------------------Start 79--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 79--------------------
#
#
# --------------------Start 80--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.1 초
# --------------------End 80--------------------
#
#
# --------------------Start 81--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.1 초
# --------------------End 81--------------------
#
#
# --------------------Start 82--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.2 초
# --------------------End 82--------------------
#
#
# --------------------Start 83--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.9 초
# --------------------End 83--------------------
#
#
# --------------------Start 84--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 84--------------------
#
#
# --------------------Start 85--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.2 초
# --------------------End 85--------------------
#
#
# --------------------Start 86--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 86--------------------
#
#
# --------------------Start 87--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.2 초
# --------------------End 87--------------------
#
#
# --------------------Start 88--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 58.0 초
# --------------------End 88--------------------
#
#
# --------------------Start 89--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.7 초
# --------------------End 89--------------------
#
#
# --------------------Start 90--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.4 초
# --------------------End 90--------------------
#
#
# --------------------Start 91--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.3 초
# --------------------End 91--------------------
#
#
# --------------------Start 92--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.3 초
# --------------------End 92--------------------
#
#
# --------------------Start 93--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.4 초
# --------------------End 93--------------------
#
#
# --------------------Start 94--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.4 초
# --------------------End 94--------------------
#
#
# --------------------Start 95--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.4 초
# --------------------End 95--------------------
#
#
# --------------------Start 96--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.7 초
# --------------------End 96--------------------
#
#
# --------------------Start 97--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.8 초
# --------------------End 97--------------------
#
#
# --------------------Start 98--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.4 초
# --------------------End 98--------------------
#
#
# --------------------Start 99--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 54.8 초
# --------------------End 99--------------------
#
#
# --------------------Start 100--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 54.3 초
# --------------------End 100--------------------
#
#
# 0 Seed Training done
#
# Files already downloaded and verified
# 1 Seed Training Start 35
# --------------------Start 1--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.002 [12800/50000]
# Batch 200 loss : 0.003 [25600/50000]
# Batch 300 loss : 0.003 [38400/50000]
# Train
#  ACC : 81.6%,  LOSS : 0.004
# Epoch Time : 0.0 분 55.5 초
# --------------------End 1--------------------
#
#
# --------------------Start 2--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.001 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.002 [38400/50000]
# Train
#  ACC : 88.9%,  LOSS : 0.003
# Epoch Time : 0.0 분 55.8 초
# --------------------End 2--------------------
#
#
# --------------------Start 3--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.001 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.002 [38400/50000]
# Train
#  ACC : 90.8%,  LOSS : 0.002
# Epoch Time : 0.0 분 57.6 초
# --------------------End 3--------------------
#
#
# --------------------Start 4--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 92.5%,  LOSS : 0.002
# Epoch Time : 0.0 분 56.7 초
# --------------------End 4--------------------
#
#
# --------------------Start 5--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 93.5%,  LOSS : 0.001
# Epoch Time : 0.0 분 55.8 초
# --------------------End 5--------------------
#
#
# --------------------Start 6--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 94.1%,  LOSS : 0.001
# Epoch Time : 0.0 분 57.9 초
# --------------------End 6--------------------
#
#
# --------------------Start 7--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 94.9%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.4 초
# --------------------End 7--------------------
#
#
# --------------------Start 8--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.001 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 95.2%,  LOSS : 0.001
# Epoch Time : 0.0 분 55.3 초
# --------------------End 8--------------------
#
#
# --------------------Start 9--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 95.7%,  LOSS : 0.001
# Epoch Time : 0.0 분 55.6 초
# --------------------End 9--------------------
#
#
# --------------------Start 10--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 96.3%,  LOSS : 0.001
# Epoch Time : 0.0 분 55.9 초
# --------------------End 10--------------------
#
#
# --------------------Start 11--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 96.2%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.3 초
# --------------------End 11--------------------
#
#
# --------------------Start 12--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.001 [38400/50000]
# Train
#  ACC : 96.7%,  LOSS : 0.001
# Epoch Time : 0.0 분 57.7 초
# --------------------End 12--------------------
#
#
# --------------------Start 13--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.2%,  LOSS : 0.001
# Epoch Time : 0.0 분 57.1 초
# --------------------End 13--------------------
#
#
# --------------------Start 14--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.3%,  LOSS : 0.001
# Epoch Time : 0.0 분 55.7 초
# --------------------End 14--------------------
#
#
# --------------------Start 15--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.5%,  LOSS : 0.001
# Epoch Time : 0.0 분 57.0 초
# --------------------End 15--------------------
#
#
# --------------------Start 16--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.5%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.2 초
# --------------------End 16--------------------
#
#
# --------------------Start 17--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.6%,  LOSS : 0.001
# Epoch Time : 0.0 분 56.2 초
# --------------------End 17--------------------
#
#
# --------------------Start 18--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.7%,  LOSS : 0.001
# Epoch Time : 0.0 분 55.9 초
# --------------------End 18--------------------
#
#
# --------------------Start 19--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 97.9%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.6 초
# --------------------End 19--------------------
#
#
# --------------------Start 20--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.2 초
# --------------------End 20--------------------
#
#
# --------------------Start 21--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.2 초
# --------------------End 21--------------------
#
#
# --------------------Start 22--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.1 초
# --------------------End 22--------------------
#
#
# --------------------Start 23--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.4 초
# --------------------End 23--------------------
#
#
# --------------------Start 24--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 24--------------------
#
#
# --------------------Start 25--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 25--------------------
#
#
# --------------------Start 26--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.5%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.0 초
# --------------------End 26--------------------
#
#
# --------------------Start 27--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.5 초
# --------------------End 27--------------------
#
#
# --------------------Start 28--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 28--------------------
#
#
# --------------------Start 29--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.8%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.3 초
# --------------------End 29--------------------
#
#
# --------------------Start 30--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 30--------------------
#
#
# --------------------Start 31--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.0 초
# --------------------End 31--------------------
#
#
# --------------------Start 32--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.4 초
# --------------------End 32--------------------
#
#
# --------------------Start 33--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.7%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.9 초
# --------------------End 33--------------------
#
#
# --------------------Start 34--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.4 초
# --------------------End 34--------------------
#
#
# --------------------Start 35--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.8%,  LOSS : 0.000
# Epoch Time : 0.0 분 55.4 초
# --------------------End 35--------------------
#
#
# --------------------Start 36--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.8%,  LOSS : 0.000
# Epoch Time : 0.0 분 54.8 초
# --------------------End 36--------------------
#
#
# --------------------Start 37--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 37--------------------
#
#
# --------------------Start 38--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 98.9%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.6 초
# --------------------End 38--------------------
#
#
# --------------------Start 39--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.3 초
# --------------------End 39--------------------
#
#
# --------------------Start 40--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 40--------------------
#
#
# --------------------Start 41--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 41--------------------
#
#
# --------------------Start 42--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.3 초
# --------------------End 42--------------------
#
#
# --------------------Start 43--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.0 초
# --------------------End 43--------------------
#
#
# --------------------Start 44--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 44--------------------
#
#
# --------------------Start 45--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.6 초
# --------------------End 45--------------------
#
#
# --------------------Start 46--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 46--------------------
#
#
# --------------------Start 47--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.8 초
# --------------------End 47--------------------
#
#
# --------------------Start 48--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 48--------------------
#
#
# --------------------Start 49--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.6 초
# --------------------End 49--------------------
#
#
# --------------------Start 50--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.1%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.0 초
# --------------------End 50--------------------
#
#
# --------------------Start 51--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.0 초
# --------------------End 51--------------------
#
#
# --------------------Start 52--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.1 초
# --------------------End 52--------------------
#
#
# --------------------Start 53--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.0 초
# --------------------End 53--------------------
#
#
# --------------------Start 54--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.1 초
# --------------------End 54--------------------
#
#
# --------------------Start 55--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.5 초
# --------------------End 55--------------------
#
#
# --------------------Start 56--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 0.0 분 56.2 초
# --------------------End 56--------------------
#
#
# --------------------Start 57--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 57.5 초
# --------------------End 57--------------------
#
#
# --------------------Start 58--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# ...
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.4 초
# --------------------End 48--------------------
#
#
# --------------------Start 49--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.4 초
# --------------------End 49--------------------
#
#
# --------------------Start 50--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.0%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.5 초
# --------------------End 50--------------------
#
#
# --------------------Start 51--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.6 초
# --------------------End 51--------------------
#
#
# --------------------Start 52--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.2 초
# --------------------End 52--------------------
#
#
# --------------------Start 53--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.3 초
# --------------------End 53--------------------
#
#
# --------------------Start 54--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.8 초
# --------------------End 54--------------------
#
#
# --------------------Start 55--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.7 초
# --------------------End 55--------------------
#
#
# --------------------Start 56--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.4 초
# --------------------End 56--------------------
#
#
# --------------------Start 57--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.2 초
# --------------------End 57--------------------
#
#
# --------------------Start 58--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 0.0 분 60.0 초
# --------------------End 58--------------------
#
#
# --------------------Start 59--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.0 초
# --------------------End 59--------------------
#
#
# --------------------Start 60--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.6 초
# --------------------End 60--------------------
#
#
# --------------------Start 61--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.5 초
# --------------------End 61--------------------
#
#
# --------------------Start 62--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.2 초
# --------------------End 62--------------------
#
#
# --------------------Start 63--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.2 초
# --------------------End 63--------------------
#
#
# --------------------Start 64--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.3%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.5 초
# --------------------End 64--------------------
#
#
# --------------------Start 65--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.4 초
# --------------------End 65--------------------
#
#
# --------------------Start 66--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.6 초
# --------------------End 66--------------------
#
#
# --------------------Start 67--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.2%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.6 초
# --------------------End 67--------------------
#
#
# --------------------Start 68--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.7 초
# --------------------End 68--------------------
#
#
# --------------------Start 69--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.3 초
# --------------------End 69--------------------
#
#
# --------------------Start 70--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.3 초
# --------------------End 70--------------------
#
#
# --------------------Start 71--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.6 초
# --------------------End 71--------------------
#
#
# --------------------Start 72--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.9 초
# --------------------End 72--------------------
#
#
# --------------------Start 73--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.9 초
# --------------------End 73--------------------
#
#
# --------------------Start 74--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.7 초
# --------------------End 74--------------------
#
#
# --------------------Start 75--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.5 초
# --------------------End 75--------------------
#
#
# --------------------Start 76--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.9 초
# --------------------End 76--------------------
#
#
# --------------------Start 77--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.9 초
# --------------------End 77--------------------
#
#
# --------------------Start 78--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.0 초
# --------------------End 78--------------------
#
#
# --------------------Start 79--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.4 초
# --------------------End 79--------------------
#
#
# --------------------Start 80--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.7 초
# --------------------End 80--------------------
#
#
# --------------------Start 81--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.2 초
# --------------------End 81--------------------
#
#
# --------------------Start 82--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.6 초
# --------------------End 82--------------------
#
#
# --------------------Start 83--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.4%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.5 초
# --------------------End 83--------------------
#
#
# --------------------Start 84--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.0 초
# --------------------End 84--------------------
#
#
# --------------------Start 85--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.3 초
# --------------------End 85--------------------
#
#
# --------------------Start 86--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.1 초
# --------------------End 86--------------------
#
#
# --------------------Start 87--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.4 초
# --------------------End 87--------------------
#
#
# --------------------Start 88--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.2 초
# --------------------End 88--------------------
#
#
# --------------------Start 89--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.7%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.5 초
# --------------------End 89--------------------
#
#
# --------------------Start 90--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.6 초
# --------------------End 90--------------------
#
#
# --------------------Start 91--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.2 초
# --------------------End 91--------------------
#
#
# --------------------Start 92--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.7%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.2 초
# --------------------End 92--------------------
#
#
# --------------------Start 93--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.1 초
# --------------------End 93--------------------
#
#
# --------------------Start 94--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.5 초
# --------------------End 94--------------------
#
#
# --------------------Start 95--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.6 초
# --------------------End 95--------------------
#
#
# --------------------Start 96--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.8%,  LOSS : 0.000
# Epoch Time : 1.0 분 2.5 초
# --------------------End 96--------------------
#
#
# --------------------Start 97--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 1.4 초
# --------------------End 97--------------------
#
#
# --------------------Start 98--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.5%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.7 초
# --------------------End 98--------------------
#
#
# --------------------Start 99--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 0.0 분 59.9 초
# --------------------End 99--------------------
#
#
# --------------------Start 100--------------------
# Batch 0 loss : 0.000 [    0/50000]
# Batch 100 loss : 0.000 [12800/50000]
# Batch 200 loss : 0.000 [25600/50000]
# Batch 300 loss : 0.000 [38400/50000]
# Train
#  ACC : 99.6%,  LOSS : 0.000
# Epoch Time : 1.0 분 0.9 초
# --------------------End 100--------------------
#
#
# 4 Seed Training done

# %% [markdown]
# # Test

# %% [markdown]
# Load Model

# %%
test_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.TenCrop(224),
    transforms.Lambda(lambda crops: torch.stack([transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(transforms.ToTensor()(crop)) for crop in crops]))
])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                    download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=100,
                                    shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified

# %%
models=[]
for i in range(5):
    model = ResNet18()
    path='D:\\Assignment\\'
    model.load_state_dict(torch.load(path+'cifar10_practice_seed_0530' + str(i) +'.pt'))
    model.eval()
    model=model.to(device)
    models.append(model)

# %% [markdown]
# Pred

# %%
# def test_loop(model, dataloader):
#     correct=0
   
#     size=len(dataloader.dataset)

#     model.eval()

#     with torch.no_grad():
#         for batch, data in enumerate(dataloader):
#             X=data[0].to(device).float()
#             y=data[1].to(device).float()
            
#             outputs=model(X)

#             _, predicted=torch.max(outputs.data, 1)
#             correct+=(predicted == y).sum().item()
#     print(f'Accuracy of the network on the 10000 test images: {(100 * (correct / size)):>0.2f} %')

# %%
# test_loop(model, testloader)

# %%
correct = 0
total = 0
cnt=0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images, labels = images.to(device), labels.to(device)  # Move the input data to the GPU
        bs, ncrops, c, h, w = images.size()       
        outputs = torch.zeros(bs, 10).to(device)  # Initialize the output tensor with zeros
        for model in models:
            model_output = model(images.view(-1, c, h, w))  # Reshape the input to (bs*10, c, h, w)
            model_output = model_output.view(bs, ncrops, -1).mean(1)  # Average the predictions of the 10 crops
            outputs += model_output
            cnt+=1
            #print(f"{cnt} model finish")
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the ensemble on the 10000 test images: %f %%' % (100 * correct / total))
# Out:
# Accuracy of the ensemble on the 10000 test images: 97.490000 %

# %%
# 제일 좋은거 lr 0,1 합친거 => 그냥 baseline임
